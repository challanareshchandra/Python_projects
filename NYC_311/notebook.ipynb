# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
import seaborn as sns
print('Import Complete')
# Out:
# Import Complete

# %%
#Reading the dataset
df = pd.read_csv('./311_Service_Requests_from_2010_to_Present.csv',low_memory=False)

# %%
df.head(25)
# Out:
#     Unique Key  ...                                  Location
# 0     32310363  ...   (40.86568153633767, -73.92350095571744)
# 1     32309934  ...  (40.775945312321085, -73.91509393898605)
# 2     32309159  ...  (40.870324522111424, -73.88852464418646)
# 3     32305098  ...   (40.83599404683083, -73.82837939584206)
# 4     32306529  ...  (40.733059618956815, -73.87416975810375)
# 5     32306554  ...   (40.66082272389114, -73.99256786342693)
# 6     32306559  ...   (40.840847591440415, -73.9373750864581)
# 7     32307009  ...   (40.83750262540012, -73.90290517326568)
# 8     32308581  ...   (40.704977164399935, -73.8326047502584)
# 9     32308391  ...  (40.623793065806524, -73.99953890121567)
# 10    32305071  ...   (40.752599671969676, -73.8933632141368)
# 11    32306260  ...   (40.85155492779258, -73.91999651358469)
# 12    32306612  ...  (40.845545043640215, -73.83358471831198)
# 13    32305074  ...   (40.68751060232221, -73.87450451131276)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364558 entries, 0 to 364557
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      364558 non-null  int64
#  1   Created Date                    364558 non-null  object
#  2   Closed Date                     362177 non-null  object
#  3   Agency                          364558 non-null  object
#  4   Agency Name                     364558 non-null  object
#  5   Complaint Type                  364558 non-null  object
#  6   Descriptor                      358057 non-null  object
#  7   Location Type                   364425 non-null  object
#  8   Incident Zip                    361560 non-null  float64
#  9   Incident Address                312859 non-null  object
#  10  Street Name                     312859 non-null  object
#  11  Cross Street 1                  307370 non-null  object
# ...

# %%
df.shape
# Out:
# (364558, 53)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364558 entries, 0 to 364557
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      364558 non-null  int64
#  1   Created Date                    364558 non-null  object
#  2   Closed Date                     362177 non-null  object
#  3   Agency                          364558 non-null  object
#  4   Agency Name                     364558 non-null  object
#  5   Complaint Type                  364558 non-null  object
#  6   Descriptor                      358057 non-null  object
#  7   Location Type                   364425 non-null  object
#  8   Incident Zip                    361560 non-null  float64
#  9   Incident Address                312859 non-null  object
#  10  Street Name                     312859 non-null  object
#  11  Cross Street 1                  307370 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
# dropping the irrelevant columns
drop_columns = ['Agency Name','Incident Address','Street Name','Cross Street 1','Cross Street 2','Intersection Street 1',
'Intersection Street 2','Address Type','Park Facility Name','Park Borough','School Name',
'School Number','School Region','School Code','School Phone Number','School Address','School City',
'School State','School Zip','School Not Found','School or Citywide Complaint','Vehicle Type',
'Taxi Company Borough','Taxi Pick Up Location','Bridge Highway Name','Bridge Highway Direction',
'Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction','Ferry Terminal Name','Landmark',
'X Coordinate (State Plane)','Y Coordinate (State Plane)','Due Date','Resolution Action Updated Date','Community Board','Facility Type',
'Location']

df = df.drop(drop_columns, axis=1)

# %%
df.shape
# Out:
# (364558, 14)

# %%
df.isnull().sum()
# Out:
# Unique Key                   0
# Created Date                 0
# Closed Date               2381
# Agency                       0
# Complaint Type               0
# Descriptor                6501
# Location Type              133
# Incident Zip              2998
# City                      2997
# Status                       0
# Resolution Description       0
# Borough                      0
# Latitude                  4030
# Longitude                 4030
# dtype: int64

# %%
df = df[df['Status'] == 'Closed']

# %%
df = df.drop(['Status'], axis = 1)

# %%
df.shape
# Out:
# (362114, 13)

# %%
# out of the remaining columns only Descriptor, Latitude and Longitude has over 1k null values
df = df[(df['Descriptor'].notnull()) & (df['Latitude'].notnull()) &(df['Longitude'].notnull())]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353988 entries, 0 to 364557
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unique Key              353988 non-null  int64
#  1   Created Date            353988 non-null  object
#  2   Closed Date             353988 non-null  object
#  3   Agency                  353988 non-null  object
#  4   Complaint Type          353988 non-null  object
#  5   Descriptor              353988 non-null  object
#  6   Location Type           353933 non-null  object
#  7   Incident Zip            353948 non-null  float64
#  8   City                    353948 non-null  object
#  9   Resolution Description  353988 non-null  object
#  10  Borough                 353988 non-null  object
#  11  Latitude                353988 non-null  float64
#  12  Longitude               353988 non-null  float64
# dtypes: float64(3), int64(1), object(9)
# ...

# %%
df.isnull().sum()
# Out:
# Unique Key                 0
# Created Date               0
# Closed Date                0
# Agency                     0
# Complaint Type             0
# Descriptor                 0
# Location Type             55
# Incident Zip              40
# City                      40
# Resolution Description     0
# Borough                    0
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
df = df[(df['Location Type'].notnull()) & (df['Incident Zip'].notnull()) &(df['City'].notnull())]
df.isnull().sum()
# Out:
# Unique Key                0
# Created Date              0
# Closed Date               0
# Agency                    0
# Complaint Type            0
# Descriptor                0
# Location Type             0
# Incident Zip              0
# City                      0
# Resolution Description    0
# Borough                   0
# Latitude                  0
# Longitude                 0
# dtype: int64

# %%
df.shape
# Out:
# (353891, 13)

# %% [markdown]
# ### The dataset has now been cleaned

# %%
cols = ['Created Date', 'Closed Date']
for col in cols:
    df[col] = pd.to_datetime(df[col],infer_datetime_format=True)
    
# creating a new column Request_Closing_Time
df['Request_Closing_Time'] = df[cols[1]] - df[cols[0]]

# viewing the info to see the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353891 entries, 0 to 364557
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unique Key              353891 non-null  int64
#  1   Created Date            353891 non-null  datetime64[ns]
#  2   Closed Date             353891 non-null  datetime64[ns]
#  3   Agency                  353891 non-null  object
#  4   Complaint Type          353891 non-null  object
#  5   Descriptor              353891 non-null  object
#  6   Location Type           353891 non-null  object
#  7   Incident Zip            353891 non-null  float64
#  8   City                    353891 non-null  object
#  9   Resolution Description  353891 non-null  object
#  10  Borough                 353891 non-null  object
#  11  Latitude                353891 non-null  float64
#  12  Longitude               353891 non-null  float64
# ...

# %%
#performing insights with data
df.describe()
# Out:
#          Unique Key   Incident Zip  ...      Longitude       Request_Closing_Time
# count  3.538910e+05  353891.000000  ...  353891.000000                     353891
# mean   3.106374e+07   10866.932143  ...     -73.924394  0 days 04:11:24.057729639
# std    7.358240e+05     575.363214  ...       0.079395  0 days 05:50:01.901604780
# min    2.960737e+07      83.000000  ...     -74.254937            0 days 00:01:01
# 25%    3.049097e+07   10451.000000  ...     -73.971468            0 days 01:15:31
# 50%    3.108240e+07   11209.000000  ...     -73.929810            0 days 02:40:05
# 75%    3.167769e+07   11238.000000  ...     -73.873072            0 days 05:13:55
# max    3.231065e+07   11697.000000  ...     -73.700715           24 days 16:52:22
#
# [8 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Complaint Type',
#        'Descriptor', 'Location Type', 'Incident Zip', 'City',
#        'Resolution Description', 'Borough', 'Latitude', 'Longitude',
#        'Request_Closing_Time'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Unique Key   Incident Zip  ...      Longitude       Request_Closing_Time
# count  3.538910e+05  353891.000000  ...  353891.000000                     353891
# mean   3.106374e+07   10866.932143  ...     -73.924394  0 days 04:11:24.057729639
# std    7.358240e+05     575.363214  ...       0.079395  0 days 05:50:01.901604780
# min    2.960737e+07      83.000000  ...     -74.254937            0 days 00:01:01
# 25%    3.049097e+07   10451.000000  ...     -73.971468            0 days 01:15:31
# 50%    3.108240e+07   11209.000000  ...     -73.929810            0 days 02:40:05
# 75%    3.167769e+07   11238.000000  ...     -73.873072            0 days 05:13:55
# max    3.231065e+07   11697.000000  ...     -73.700715           24 days 16:52:22
#
# [8 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Complaint Type',
#        'Descriptor', 'Location Type', 'Incident Zip', 'City',
#        'Resolution Description', 'Borough', 'Latitude', 'Longitude',
#        'Request_Closing_Time'],
#       dtype='object')

# %%
df['Agency'].value_counts()
#since every compliant is under the same agency, we are analyzing the compliant types recived by the agency.
# Out:
# NYPD    353891
# Name: Agency, dtype: int64

# %%
print('Major Complaints \n')
print(df['Complaint Type'].value_counts())
# Out:
# Major Complaints
#
# Blocked Driveway            100455
# Illegal Parking              91057
# Noise - Street/Sidewalk      50791
# Noise - Commercial           43623
# Derelict Vehicle             21419
# Noise - Vehicle              19122
# Animal Abuse                 10500
# Traffic                       5161
# Vending                       4162
# Noise - Park                  3994
# Drinking                      1399
# Noise - House of Worship      1059
# Posting Advertisement          678
# Disorderly Youth               314
# Graffiti                       157
# Name: Complaint Type, dtype: int64

# %%
#ploting against the bar graph
df['Complaint Type'].value_counts().plot(kind = 'barh', figsize=(12,6), title='Major compliants',xlabel='Type of compliant', ylabel='Count', grid=True)
# Out:
# <AxesSubplot:title={'center':'Major compliants'}, ylabel='Type of compliant'>

# %%
print('Descriptor problems \n')
print(df['Descriptor'].value_counts())
# Out:
# Descriptor problems
#
# No Access                         75590
# Loud Music/Party                  68668
# Posted Parking Sign Violation     26817
# Partial Access                    24865
# Loud Talking                      23458
# With License Plate                21419
# Blocked Hydrant                   19717
# Commercial Overnight Parking      14629
# Blocked Sidewalk                  13615
# Car/Truck Music                   11777
# Double Parked Blocking Traffic     6952
# Engine Idling                      5261
# Neglected                          5114
# Double Parked Blocking Vehicle     5082
# Banging/Pounding                   4876
# Car/Truck Horn                     4436
# Congestion/Gridlock                3208
# Other (complaint details)          2480
# In Prohibited Area                 2197
# Overnight Commercial Storage       2090
# Unlicensed                         1965
# Unauthorized Bus Layover           1579
# Truck Route Violation              1120
# ...

# %%
df['Descriptor'].value_counts().head(25).plot(kind='barh', grid=True,figsize=(15,10), title='Top 25 Descriptors')
# Out:
# <AxesSubplot:title={'center':'Top 25 Descriptors'}>

# %%
print('Location description \n')
print(df['Location Type'].value_counts())
# Out:
# Location description
#
# Street/Sidewalk               294128
# Store/Commercial               24148
# Club/Bar/Restaurant            21306
# Residential Building/House      7466
# Park/Playground                 4336
# House of Worship                1059
# Residential Building             529
# House and Store                  245
# Highway                          242
# Parking Lot                      166
# Commercial                       106
# Vacant Lot                        95
# Roadway Tunnel                    39
# Subway Station                    26
# Name: Location Type, dtype: int64

# %%
df['Location Type'].value_counts().head(15).plot(kind='barh', grid=True, figsize=(12, 6), title='Location description')
# Out:
# <AxesSubplot:title={'center':'Location description'}>

# %%
df['City'].value_counts().head(10)
# Out:
# BROOKLYN         117268
# NEW YORK          72847
# BRONX             48640
# STATEN ISLAND     15191
# JAMAICA            8772
# ASTORIA            7910
# FLUSHING           7431
# RIDGEWOOD          6348
# CORONA             5346
# WOODSIDE           4300
# Name: City, dtype: int64

# %%
df['City'].value_counts().head(10).plot(kind='barh', grid=True, figsize=(10, 5), title='City Column', ylabel='Cities')
plt.xlabel('Complaint Counts')
# Out:
# Text(0.5, 0, 'Complaint Counts')

# %%
df['Borough'].value_counts().head(10).plot(kind='barh', grid=True, figsize=(10, 5), title='Borough Column', ylabel='Borough')
plt.xlabel('Complaint Counts')
# Out:
# Text(0.5, 0, 'Complaint Counts')

# %%
#top compliants
top_10_complaints = df['Complaint Type'].value_counts()[:10].keys()
top_10_complaints
# Out:
# Index(['Blocked Driveway', 'Illegal Parking', 'Noise - Street/Sidewalk',
#        'Noise - Commercial', 'Derelict Vehicle', 'Noise - Vehicle',
#        'Animal Abuse', 'Traffic', 'Vending', 'Noise - Park'],
#       dtype='object')

# %%
borough_complaints = df.groupby(['Borough', 'Complaint Type']).size().unstack()
borough_complaints = borough_complaints[top_10_complaints]
borough_complaints
# Out:
# Complaint Type  Blocked Driveway  Illegal Parking  ...  Vending  Noise - Park
# Borough                                            ...
# BRONX                    17048.0           9852.0  ...    431.0         523.0
# BROOKLYN                 36414.0          33446.0  ...    574.0        1557.0
# MANHATTAN                 2686.0          14372.0  ...   2619.0        1200.0
# QUEENS                   41463.0          27168.0  ...    513.0         647.0
# STATEN ISLAND             2844.0           6218.0  ...     25.0          67.0
# Unspecified                  NaN              1.0  ...      NaN           NaN
#
# [6 rows x 10 columns]

# %%
col_number = 2
row_number = 3
fig, axes = plt.subplots(row_number,col_number, figsize=(20,15))

for i, (label,col) in enumerate(borough_complaints.iteritems()):
    ax = axes[int(i/col_number), int(i%col_number)]
    col = col.sort_values(ascending=True)[:20]
    col.plot(kind='barh', ax=ax, grid=True)
    ax.set_title(label)
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [36], in <cell line: 5>()
#       3 fig, axes = plt.subplots(row_number,col_number, figsize=(20,15))
#       5 for i, (label,col) in enumerate(borough_complaints.iteritems()):
# ----> 6     ax = axes[int(i/col_number), int(i%col_number)]
#       7     col = col.sort_values(ascending=True)[:20]
#       8     col.plot(kind='barh', ax=ax, grid=True)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %% [markdown]
# ## frequency comparsion across the cities

# %%
df_perfect_Blocked_Driveway = df[df['Complaint Type'] == 'Blocked Driveway']
df_perfect_Blocked_Driveway.plot(kind='hexbin', x='Longitude', y='Latitude', gridsize=40,
    colormap = 'jet',mincnt=1,title = 'Blocked Driveway issues across NYC\n', figsize=(5,5)).axis('equal')
# Out:
# (-74.28064686999934, -73.67309922236329, 40.48276254832783, 40.93330694343947)

# %%
df_Brooklyn = df[df['Borough']=='BROOKLYN']
df.shape
# Out:
# (353891, 14)

# %%
df_Brooklyn[['Longitude', 'Latitude']].plot(kind='scatter',
    x='Longitude', y='Latitude', figsize=(7,7),title = 'Complaints concentration across Brooklyn').axis('equal')
# Out:
# (-74.05061403028367, -73.84647934348564, 40.563150823850876, 40.74729501421672)

# %%
df_Brooklyn.plot(kind='hexbin', x='Longitude', y='Latitude', gridsize=40,
    colormap = 'jet',mincnt=1,title = 'Complaints concentration across Brooklyn\n', figsize=(10,6)).axis('equal')
# Out:
# (-74.05061403048781, -73.8464793432815, 40.563150823850876, 40.74729501421672)

# %%
df[df['Complaint Type'] == 'Blocked Driveway']['Descriptor'].value_counts()
# Out:
# No Access         75590
# Partial Access    24865
# Name: Descriptor, dtype: int64

# %%
df_Brook_BD = df_Brooklyn[df_Brooklyn['Complaint Type'] == 'Blocked Driveway']

# %%
df_Brook_BD[df_Brook_BD['Complaint Type'] == 'Blocked Driveway'].plot(
    kind='hexbin', x='Longitude', y='Latitude', gridsize=40,title = 'Blocked Driveway complaints concentration across Brooklyn\n',
    colormap='jet', mincnt=1, figsize=(10,6)).axis('equal')
# Out:
# (-74.04994269716303, -73.84653003063751, 40.56459183795005, 40.746496092182724)

# %%
# Creating a column Request_Closing_Time_in_Hours for time in Hours
# and we will say the said complaint has been closed under x hours
df['Request_Closing_Time_in_Hours'] = df['Request_Closing_Time'].astype('timedelta64[h]')+1

# viewing the Two columns side by side for first 20 entries
df[['Request_Closing_Time', 'Request_Closing_Time_in_Hours']].head(20)
# Out:
#    Request_Closing_Time  Request_Closing_Time_in_Hours
# 0       0 days 00:55:30                            1.0
# 1       0 days 01:27:13                            2.0
# 2       0 days 04:51:34                            5.0
# 3       0 days 07:45:27                            8.0
# 4       0 days 03:27:44                            4.0
# 5       0 days 01:53:41                            2.0
# 6       0 days 01:58:22                            2.0
# 7       0 days 01:48:49                            2.0
# 8       0 days 08:33:34                            9.0
# 9       0 days 01:23:42                            2.0
# 10      0 days 07:48:40                            8.0
# 11      0 days 11:07:11                           12.0
# 12      0 days 02:29:56                            3.0
# 13      0 days 08:30:49                            9.0
# 14      0 days 10:29:45                           11.0
# 15      0 days 15:33:27                           16.0
# ...

# %%
data_avg_time_in_hrs = df.groupby(['City', 'Complaint Type'])['Request_Closing_Time_in_Hours'].mean()
data_avg_time_in_hrs.head(10)
# Out:
# City     Complaint Type
# ARVERNE  Animal Abuse                2.826087
#          Blocked Driveway            2.800000
#          Derelict Vehicle            3.625000
#          Disorderly Youth            4.000000
#          Drinking                    1.000000
#          Graffiti                    2.000000
#          Illegal Parking             2.822581
#          Noise - Commercial          3.000000
#          Noise - House of Worship    2.357143
#          Noise - Park                1.500000
# Name: Request_Closing_Time_in_Hours, dtype: float64

# %%
# Creating a column Request_Closing_Time_in_Seconds for time in seconds
df['Request_Closing_Time_in_Seconds'] = df['Request_Closing_Time'].astype('timedelta64[s]')

# viewing the Three columns side by side
df[['Request_Closing_Time', 'Request_Closing_Time_in_Hours','Request_Closing_Time_in_Seconds']].head(10)
# Out:
#   Request_Closing_Time  ...  Request_Closing_Time_in_Seconds
# 0      0 days 00:55:30  ...                           3330.0
# 1      0 days 01:27:13  ...                           5233.0
# 2      0 days 04:51:34  ...                          17494.0
# 3      0 days 07:45:27  ...                          27927.0
# 4      0 days 03:27:44  ...                          12464.0
# 5      0 days 01:53:41  ...                           6821.0
# 6      0 days 01:58:22  ...                           7102.0
# 7      0 days 01:48:49  ...                           6529.0
# 8      0 days 08:33:34  ...                          30814.0
# 9      0 days 01:23:42  ...                           5022.0
#
# [10 rows x 3 columns]

# %%
data_avg_in_seconds = df.groupby(['City', 'Complaint Type']).Request_Closing_Time_in_Seconds.mean()
data_avg_in_seconds.head(10)
# Out:
# City     Complaint Type
# ARVERNE  Animal Abuse                 8399.195652
#          Blocked Driveway             8318.840000
#          Derelict Vehicle            11394.000000
#          Disorderly Youth            12928.500000
#          Drinking                      859.000000
#          Graffiti                     5508.000000
#          Illegal Parking              8406.080645
#          Noise - Commercial           8234.000000
#          Noise - House of Worship     6653.428571
#          Noise - Park                 4638.000000
# Name: Request_Closing_Time_in_Seconds, dtype: float64

# %%
df['Request_Closing_Time'].describe()
# Out:
# count                       353891
# mean     0 days 04:11:24.057729639
# std      0 days 05:50:01.901604780
# min                0 days 00:01:01
# 25%                0 days 01:15:31
# 50%                0 days 02:40:05
# 75%                0 days 05:13:55
# max               24 days 16:52:22
# Name: Request_Closing_Time, dtype: object

# %%
mean_hrs = df['Request_Closing_Time_in_Hours'].mean()
std_hrs = df['Request_Closing_Time_in_Hours'].std()

mean_seconds = df['Request_Closing_Time_in_Seconds'].mean()
std_seconds = df['Request_Closing_Time_in_Seconds'].std()

print('The mean hours is {0:.2f} hours and mean Secondsis {1:.2f} seconds'.format(mean_hrs, mean_seconds))
print('The standard hours is {0:.2f} hours and standard Seconds is {1:.2f} seconds'.format(std_hrs, std_seconds))
# Out:
# The mean hours is 4.70 hours and mean Secondsis 15084.06 seconds
# The standard hours is 5.84 hours and standard Seconds is 21001.90 seconds

# %%
import datetime
df['Year-Month'] = df['Created Date'].apply(lambda x:datetime.datetime.strftime(x, '%Y-%m'))

# %%
df['Year-Month'].unique()
# Out:
# array(['2015-12', '2015-11', '2015-10', '2015-09', '2015-08', '2015-07',
#        '2015-06', '2015-05', '2015-04', '2015-03', '2015-02', '2015-01'],
#       dtype=object)

# %%
# plotting the month column
#dataset['Year-Month'].value_counts().plot()
monthly_incidents =  df.groupby('Year-Month').size().plot(figsize=(12,5),
                                                               title='Incident Counts on a monthly basis', ylabel='Counts')

# %%
df.groupby(['Year-Month','Borough']).size().unstack().plot(figsize=(15,7))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
df.groupby(['Borough', 'Year-Month']).size().unstack().plot(figsize=(15,7))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
df.groupby(['Year-Month','Borough'])['Request_Closing_Time_in_Hours'].mean().unstack().plot(figsize=(15,7),
                                                                        title='Processing time per Borough on a monthly basis');

# %% [markdown]
# Bronx has the maximum Processing time every month even though it has the least complaints.

# %%
# similarly for Complaints per Borough
top_borough = df['Borough'].value_counts().keys()

complaint_per_borough = df.groupby(['Complaint Type', 'Borough']).size().unstack()
complaint_per_borough = complaint_per_borough[top_borough]
complaint_per_borough
# Out:
# Borough                   BROOKLYN   QUEENS  ...  STATEN ISLAND  Unspecified
# Complaint Type                               ...
# Animal Abuse                3185.0   2637.0  ...          786.0          NaN
# Blocked Driveway           36414.0  41463.0  ...         2844.0          NaN
# Derelict Vehicle            6243.0   9911.0  ...         2180.0          NaN
# Disorderly Youth              79.0     64.0  ...           25.0          NaN
# Drinking                     291.0    395.0  ...          188.0          NaN
# Graffiti                      60.0     51.0  ...            6.0          NaN
# Illegal Parking            33446.0  27168.0  ...         6218.0          1.0
# Noise - Commercial         13847.0   7386.0  ...          783.0          NaN
# Noise - House of Worship     387.0    347.0  ...           18.0          NaN
# Noise - Park                1557.0    647.0  ...           67.0          NaN
# Noise - Street/Sidewalk    13942.0   4663.0  ...          884.0          NaN
# ...

# %%
# Plotting Complaints per Borough
col_number = 2
row_number = 3
fig, axes = plt.subplots(row_number,col_number, figsize=(12,12))

for i, (label,col) in enumerate(complaint_per_borough.iteritems()):
    ax = axes[int(i/col_number), i%col_number]
    col = col.sort_values(ascending=True)[:15]
    col.plot(kind='barh', ax=ax, grid=True)
    ax.set_title(label)
    
plt.tight_layout()

# %% [markdown]
# ### Average closing times as per city

# %%
r1=pd.DataFrame(df.groupby('City')['Request_Closing_Time'].mean()).sort_values('Request_Closing_Time')
print(r1)
# Out:
#                          Request_Closing_Time
# City
# ARVERNE             0 days 02:19:22.849206349
# ROCKAWAY PARK       0 days 02:19:55.467233009
# OAKLAND GARDENS     0 days 02:34:01.259831460
# LITTLE NECK         0 days 02:34:59.395218002
# BAYSIDE             0 days 02:40:13.856124432
# FAR ROCKAWAY        0 days 02:41:16.456852791
# QUEENS              0 days 02:44:50.424242424
# NEW YORK            0 days 02:53:31.093813060
# FLUSHING            0 days 02:57:39.233885076
# FOREST HILLS        0 days 03:03:25.410637278
# WHITESTONE          0 days 03:08:03.984581497
# CORONA              0 days 03:09:03.862139917
# COLLEGE POINT       0 days 03:10:23.898701298
# JACKSON HEIGHTS     0 days 03:11:08.111164350
# ELMHURST            0 days 03:14:02.048125184
# FRESH MEADOWS       0 days 03:20:22.430504305
# REGO PARK           0 days 03:22:25.852614015
# BREEZY POINT        0 days 03:25:11.870967741
# CENTRAL PARK        0 days 03:26:55.281818181
# ...

# %% [markdown]
# ## Statistical test

# %%
def getDfSummary(input_data):
    number_nan = input_data.isnull().sum()
    number_distinct = input_data.nunique(dropna=True)
    output_data = pd.DataFrame({'number_nan':number_nan,'number_distinct':number_distinct})
    return output_data

# %%
getDfSummary(df_Brook_BD)
# Out:
#                         number_nan  number_distinct
# Unique Key                       0            36414
# Created Date                     0            36380
# Closed Date                      0            35851
# Agency                           0                1
# Complaint Type                   0                1
# Descriptor                       0                2
# Location Type                    0                1
# Incident Zip                     0               38
# City                             0                1
# Resolution Description           0               11
# Borough                          0                1
# Latitude                         0            18326
# Longitude                        0            18290
# Request_Closing_Time             0            21873

# %%
df['Request_Closing_Time_in_Hours'] = df['Request_Closing_Time'].astype('timedelta64[h]')+1

# viewing the Two columns side by side for first 20 entries
df[['Request_Closing_Time', 'Request_Closing_Time_in_Hours']].head(20)
# Out:
#    Request_Closing_Time  Request_Closing_Time_in_Hours
# 0       0 days 00:55:30                            1.0
# 1       0 days 01:27:13                            2.0
# 2       0 days 04:51:34                            5.0
# 3       0 days 07:45:27                            8.0
# 4       0 days 03:27:44                            4.0
# 5       0 days 01:53:41                            2.0
# 6       0 days 01:58:22                            2.0
# 7       0 days 01:48:49                            2.0
# 8       0 days 08:33:34                            9.0
# 9       0 days 01:23:42                            2.0
# 10      0 days 07:48:40                            8.0
# 11      0 days 11:07:11                           12.0
# 12      0 days 02:29:56                            3.0
# 13      0 days 08:30:49                            9.0
# 14      0 days 10:29:45                           11.0
# 15      0 days 15:33:27                           16.0
# ...

# %%
data_avg_time_in_hrs = df.groupby(['City', 'Complaint Type'])['Request_Closing_Time_in_Hours'].mean()
data_avg_time_in_hrs.head(15)
# Out:
# City     Complaint Type
# ARVERNE  Animal Abuse                2.826087
#          Blocked Driveway            2.800000
#          Derelict Vehicle            3.625000
#          Disorderly Youth            4.000000
#          Drinking                    1.000000
#          Graffiti                    2.000000
#          Illegal Parking             2.822581
#          Noise - Commercial          3.000000
#          Noise - House of Worship    2.357143
#          Noise - Park                1.500000
#          Noise - Street/Sidewalk     2.517241
#          Noise - Vehicle             2.222222
#          Traffic                     2.000000
#          Vending                     1.000000
# ASTORIA  Animal Abuse                5.282353
# Name: Request_Closing_Time_in_Hours, dtype: float64

# %%
# Creating a column Request_Closing_Time_in_Seconds for time in seconds
df['Request_Closing_Time_in_Seconds'] = df['Request_Closing_Time'].astype('timedelta64[s]')

# viewing the Three columns side by side
df[['Request_Closing_Time', 'Request_Closing_Time_in_Hours','Request_Closing_Time_in_Seconds']].head()
# Out:
#   Request_Closing_Time  ...  Request_Closing_Time_in_Seconds
# 0      0 days 00:55:30  ...                           3330.0
# 1      0 days 01:27:13  ...                           5233.0
# 2      0 days 04:51:34  ...                          17494.0
# 3      0 days 07:45:27  ...                          27927.0
# 4      0 days 03:27:44  ...                          12464.0
#
# [5 rows x 3 columns]

# %%
data_avg_in_seconds = df.groupby(['City', 'Complaint Type']).Request_Closing_Time_in_Seconds.mean()
data_avg_in_seconds.head(15)
# Out:
# City     Complaint Type
# ARVERNE  Animal Abuse                 8399.195652
#          Blocked Driveway             8318.840000
#          Derelict Vehicle            11394.000000
#          Disorderly Youth            12928.500000
#          Drinking                      859.000000
#          Graffiti                     5508.000000
#          Illegal Parking              8406.080645
#          Noise - Commercial           8234.000000
#          Noise - House of Worship     6653.428571
#          Noise - Park                 4638.000000
#          Noise - Street/Sidewalk      7173.206897
#          Noise - Vehicle              6051.111111
#          Traffic                      4014.000000
#          Vending                      1735.000000
# ASTORIA  Animal Abuse                17206.882353
# Name: Request_Closing_Time_in_Seconds, dtype: float64

# %%
df['Request_Closing_Time'].describe()
# Out:
# count                       353891
# mean     0 days 04:11:24.057729639
# std      0 days 05:50:01.901604780
# min                0 days 00:01:01
# 25%                0 days 01:15:31
# 50%                0 days 02:40:05
# 75%                0 days 05:13:55
# max               24 days 16:52:22
# Name: Request_Closing_Time, dtype: object

# %%
mean_hrs = df['Request_Closing_Time_in_Hours'].mean()
std_hrs = df['Request_Closing_Time_in_Hours'].std()

mean_seconds = df['Request_Closing_Time_in_Seconds'].mean()
std_seconds = df['Request_Closing_Time_in_Seconds'].std()

print('The mean hours is {0:.2f} hours and mean Secondsis {1:.2f} seconds'.format(mean_hrs, mean_seconds))
print('The standard hours is {0:.2f} hours and standard Seconds is {1:.2f} seconds'.format(std_hrs, std_seconds))
# Out:
# The mean hours is 4.70 hours and mean Secondsis 15084.06 seconds
# The standard hours is 5.84 hours and standard Seconds is 21001.90 seconds

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %%
city_type = pd.crosstab(df['City'], df['Complaint Type'])
city_type.head()
# Out:
# Complaint Type  Animal Abuse  Blocked Driveway  ...  Traffic  Vending
# City                                            ...
# ARVERNE                   46                50  ...        1        1
# ASTORIA                  170              3436  ...       60       57
# Astoria                    0               159  ...        0        0
# BAYSIDE                   53               513  ...        9        2
# BELLEROSE                 15               138  ...        9        0
#
# [5 rows x 15 columns]

# %%
table = city_type 
stat, p, dof, expected = chi2_contingency(table)

# %%
print('The Degrees of Freedom are : {}'. format(dof))
print('The P-Value of the Testing is {}: '.format(p))
print('Expected values : \n')
print(expected)
# Out:
# The Degrees of Freedom are : 728
# The P-Value of the Testing is 0.0:
# Expected values :
#
# [[7.47687847e+00 7.15323645e+01 1.52521200e+01 2.23594271e-01
#   9.96205046e-01 1.11797135e-01 6.48402022e+01 3.10632257e+01
#   7.54096600e-01 2.84406215e+00 3.61674414e+01 1.36164638e+01
#   4.82792724e-01 3.67506379e+00 2.96369221e+00]
#  [2.34690908e+02 2.24532144e+03 4.78747100e+02 7.01837571e+00
#   3.12697695e+01 3.50918786e+00 2.03526190e+03 9.75040139e+02
#   2.36702544e+01 8.92719510e+01 1.13525580e+03 4.27405670e+02
#   1.51543272e+01 1.15356169e+02 9.30270055e+01]
#  [2.68514882e+01 2.56892023e+02 5.47744786e+01 8.02987361e-01
#   3.57764114e+00 4.01493680e-01 2.32858663e+02 1.11556426e+02
#   2.70816438e+00 1.02137946e+01 1.29887041e+02 4.89003959e+01
#   1.73383895e+00 1.31981458e+01 1.06434185e+01]
#  [4.57810456e+01 4.37993803e+02 9.33889729e+01 1.36907127e+00
#   6.09977931e+00 6.84535634e-01 3.97017587e+02 1.90200624e+02
# ...

# %%
# interpreting test statistics
prob = 0.95 # as aplha is considered 0.05
critical_value = chi2.ppf(prob, dof)
critical_value
# Out:
# 791.8799091140163

# %%
print('Probability = {}, Critical Value = {}, Test statistic = {}'.format(prob, critical_value, stat))
print()
if abs(stat) >= critical_value:
    print('Dependent (Reject H0 or Null Hypothesis)')
else:
    print('Independent (Failed to reject Null Hypothesis)')


# interpreting the P-Value
alpha = 1 - prob
print('Significance : %.3f, P-Value : %.2f'%(alpha, p))
if p <= alpha:
    print('Dependent (Reject H0 or Null Hypothesis)')
else:
    print('Independent (Failed to reject Null Hypothesis)')
# Out:
# Probability = 0.95, Critical Value = 791.8799091140163, Test statistic = 125812.28625715601
#
# Dependent (Reject H0 or Null Hypothesis)
# Significance : 0.050, P-Value : 0.00
# Dependent (Reject H0 or Null Hypothesis)
